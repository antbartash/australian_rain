# %% [markdown]
# <a href="https://colab.research.google.com/github/antbartash/australian_rain/blob/main/MicrosoftNNI/SimulatedAnnealing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup Microsoft NNI on Google Colab / Kaggle

# %%
# install nni
! pip install nni

# download ngrok and unzip it
! wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
! unzip ngrok-stable-linux-amd64.zip
# Out:
# Collecting nni
#   Obtaining dependency information for nni from https://files.pythonhosted.org/packages/0b/ed/7a061494753317e0943be1685a4690d05e2e610e5b19aa2823547b584950/nni-3.0-py3-none-manylinux1_x86_64.whl.metadata
#   Downloading nni-3.0-py3-none-manylinux1_x86_64.whl.metadata (19 kB)
# Collecting astor (from nni)
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (from nni) (2.2.1)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from nni) (0.4.6)
# Collecting filelock<3.12 (from nni)
#   Downloading filelock-3.11.0-py3-none-any.whl (10.0 kB)
# Collecting json-tricks>=3.15.5 (from nni)
#   Obtaining dependency information for json-tricks>=3.15.5 from https://files.pythonhosted.org/packages/ae/fd/e3edcf827e7f9c17c5ea1a192841dcfb1dd575a7518c25c5cadd921625b1/json_tricks-3.17.3-py2.py3-none-any.whl.metadata
#   Downloading json_tricks-3.17.3-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: nvidia-ml-py in /opt/conda/lib/python3.10/site-packages (from nni) (11.495.46)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from nni) (21.3)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from nni) (2.0.3)
# Requirement already satisfied: prettytable in /opt/conda/lib/python3.10/site-packages (from nni) (3.8.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from nni) (5.9.3)
# Collecting PythonWebHDFS (from nni)
#   Downloading PythonWebHDFS-0.2.3-py3-none-any.whl (10 kB)
# Requirement already satisfied: pyyaml>=5.4 in /opt/conda/lib/python3.10/site-packages (from nni) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from nni) (2.31.0)
# Requirement already satisfied: responses in /opt/conda/lib/python3.10/site-packages (from nni) (0.18.0)
# Collecting schema (from nni)
#   Downloading schema-0.7.5-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-learn>=0.24.1 in /opt/conda/lib/python3.10/site-packages (from nni) (1.2.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nni) (4.66.1)
# Collecting typeguard<4.1.3,>=3.0.0 (from nni)
#   Obtaining dependency information for typeguard<4.1.3,>=3.0.0 from https://files.pythonhosted.org/packages/bb/bd/dc7da80c95c920ee2b575e64901b5962ca4a1271b5f3cf6c27242aa0aafc/typeguard-4.1.2-py3-none-any.whl.metadata
#   Downloading typeguard-4.1.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting typing-extensions>=4.7.0 (from nni)
#   Obtaining dependency information for typing-extensions>=4.7.0 from https://files.pythonhosted.org/packages/b7/f4/6a90020cd2d93349b442bfcb657d0dc91eee65491600b2cb1d388bc98e6b/typing_extensions-4.9.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: websockets>=10.1 in /opt/conda/lib/python3.10/site-packages (from nni) (12.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from nni) (1.24.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from nni) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.24.1->nni) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.24.1->nni) (3.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->nni) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->nni) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->nni) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->nni) (2023.3)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prettytable->nni) (0.2.6)
# Requirement already satisfied: simplejson in /opt/conda/lib/python3.10/site-packages (from PythonWebHDFS->nni) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->nni) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->nni) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->nni) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->nni) (2023.11.17)
# Collecting contextlib2>=0.5.5 (from schema->nni)
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->nni) (1.16.0)
# Downloading nni-3.0-py3-none-manylinux1_x86_64.whl (61.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 MB 15.3 MB/s eta 0:00:0000:01m00:01
# Downloading json_tricks-3.17.3-py2.py3-none-any.whl (27 kB)
# Downloading typeguard-4.1.2-py3-none-any.whl (33 kB)
# Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Installing collected packages: json-tricks, typing-extensions, filelock, contextlib2, astor, typeguard, schema, PythonWebHDFS, nni
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.12.2
#     Uninstalling filelock-3.12.2:
#       Successfully uninstalled filelock-3.12.2
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 2.13.3
#     Uninstalling typeguard-2.13.3:
#       Successfully uninstalled typeguard-2.13.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.7 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.3 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# cuml 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# dask-cudf 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.3 which is incompatible.
# jupyterlab 4.0.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.1 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.1 requires jupyterlab<5.0.0a0,>=4.0.6, but you have jupyterlab 4.0.5 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.24.3 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.4 which is incompatible.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.9.0 which is incompatible.
# tensorflow-addons 0.23.0 requires typeguard<3.0.0,>=2.7, but you have typeguard 4.1.2 which is incompatible.
# tensorflow-probability 0.21.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# tensorflowjs 4.14.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.
# virtualenv 20.21.0 requires platformdirs<4,>=2.4, but you have platformdirs 4.1.0 which is incompatible.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.3 which is incompatible.
# ydata-profiling 4.5.1 requires typeguard<3,>=2.13.2, but you have typeguard 4.1.2 which is incompatible.
# Successfully installed PythonWebHDFS-0.2.3 astor-0.8.1 contextlib2-21.6.0 filelock-3.11.0 json-tricks-3.17.3 nni-3.0 schema-0.7.5 typeguard-4.1.2 typing-extensions-4.7.1
# --2023-12-28 18:37:41--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.202.168.65, 18.205.222.128, 54.237.133.81, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.202.168.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13921656 (13M) [application/octet-stream]
# Saving to: 'ngrok-stable-linux-amd64.zip'
#
# ngrok-stable-linux- 100%[===================>]  13.28M  37.0MB/s    in 0.4s
#
# 2023-12-28 18:37:42 (37.0 MB/s) - 'ngrok-stable-linux-amd64.zip' saved [13921656/13921656]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
! ./ngrok authtoken 2ZqSaEGuFWdJVe4YADpDuGtZ1R9_2L3tHZaAHSSavE6N96jo4 # YOUR_AUTH_TOKEN
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# clone the github repo to get the model.py file
! git clone https://github.com/antbartash/australian_rain.git
# Out:
# Cloning into 'australian_rain'...
# remote: Enumerating objects: 246, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 246 (delta 81), reused 95 (delta 54), pack-reused 101
# Receiving objects: 100% (246/246), 8.38 MiB | 18.26 MiB/s, done.
# Resolving deltas: 100% (126/126), done.

# %%
from nni.experiment import Experiment
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
hyperparameter_space = {
    'n_estimators': {'_type': 'randint', '_value': [100, 2000]},
    'learning_rate': {'_type': 'loguniform', '_value': [1e-6, 0.5]},
    'depth': {'_type': 'randint', '_value': [1, 10]},
    'l2_leaf_reg': {'_type': 'uniform', '_value': [0.0, 100.0]},
    # 'random_strength': {'_type': 'uniform', '_value': [0.0, 100.0]}, # CPU only
    'bagging_temperature': {'_type': 'uniform', '_value': [0.0, 100.0]},
    'grow_policy': {'_type': 'choice', '_value': ['SymmetricTree', 'Depthwise']},
    'scale_pos_weight': {'_type': 'uniform', '_value': [1, 4]}
}

# %%
experiment = Experiment('local')
experiment.config.experiment_name = 'CatBoost_NNI_TPE'
experiment.config.tuner.name = 'TPE'
experiment.config.tuner.class_args = {
    # minimal config
    'optimize_mode': 'maximize',
    'seed': 42,
    # advanced config
    'tpe_args': {
        'n_startup_jobs': 10,
        'n_ei_candidates': 20,
        'linear_forgetting': 100,
        'gamma': 0.5
    }
}
experiment.config.experiment_working_directory = '/kaggle/working/'
experiment.config.trial_command = 'python3 /kaggle/working/australian_rain/MicrosoftNNI/model_GPU.py'
experiment.config.trial_code_directory = '.'
experiment.config.search_space = hyperparameter_space
experiment.config.max_trial_number = 100
experiment.config.trial_concurrency = 1
experiment.config.max_experiment_duration = '1h'

# %%
get_ipython().system_raw('./ngrok http 5000 &')

# %%
! curl -s http://localhost:4040/api/tunnels # don't change the port number 4040
# Out:
# {"tunnels":[{"name":"command_line","uri":"/api/tunnels/command_line","public_url":"https://f7a1-34-172-112-41.ngrok-free.app","proto":"https","config":{"addr":"http://localhost:5000","inspect":true},"metrics":{"conns":{"count":0,"gauge":0,"rate1":0,"rate5":0,"rate15":0,"p50":0,"p90":0,"p95":0,"p99":0},"http":{"count":0,"rate1":0,"rate5":0,"rate15":0,"p50":0,"p90":0,"p95":0,"p99":0}}},{"name":"command_line (http)","uri":"/api/tunnels/command_line%20%28http%29","public_url":"http://f7a1-34-172-112-41.ngrok-free.app","proto":"http","config":{"addr":"http://localhost:5000","inspect":true},"metrics":{"conns":{"count":0,"gauge":0,"rate1":0,"rate5":0,"rate15":0,"p50":0,"p90":0,"p95":0,"p99":0},"http":{"count":0,"rate1":0,"rate5":0,"rate15":0,"p50":0,"p90":0,"p95":0,"p99":0}}}],"uri":"/api/tunnels"}

# %%
experiment.run(5000, wait_completion=True, debug=False)
# Out:
# [2023-12-28 18:37:57] Creating experiment, Experiment ID: 538lknex
# [2023-12-28 18:37:57] Starting web server...
# [2023-12-28 18:37:58] Setting up...
# [2023-12-28 18:37:58] Web portal URLs: http://127.0.0.1:5000 http://172.19.2.2:5000
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# True

# %%
best_trial = sorted(experiment.export_data(), key=lambda x: x.value, reverse=True)[0]
print(best_trial.parameter)
# Out:
# {'n_estimators': 265, 'learning_rate': 0.16067785482547484, 'depth': 8, 'l2_leaf_reg': 28.487942919082577, 'bagging_temperature': 0.5423117838392528, 'grow_policy': 'SymmetricTree', 'scale_pos_weight': 1.3075498445065654}

# %%
# zip NNI logs
# !zip -r TPELogs.zip /kaggle/working/538lknex
# Out:
#   adding: kaggle/working/538lknex/ (stored 0%)
#   adding: kaggle/working/538lknex/log/ (stored 0%)
#   adding: kaggle/working/538lknex/log/experiment.log (deflated 51%)
#   adding: kaggle/working/538lknex/log/dispatcher.log (deflated 54%)
#   adding: kaggle/working/538lknex/log/nnimanager.log (deflated 91%)
#   adding: kaggle/working/538lknex/checkpoint/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Nl9ir/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Nl9ir/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Nl9ir/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Nl9ir/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/TlTl7/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/TlTl7/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/TlTl7/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/TlTl7/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Vzv3n/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Vzv3n/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Vzv3n/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Vzv3n/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/SSKrG/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/SSKrG/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/SSKrG/trial.log (deflated 14%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/SSKrG/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Hcxy0/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Hcxy0/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Hcxy0/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Hcxy0/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/yMa3C/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/yMa3C/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/yMa3C/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/yMa3C/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/gY0FR/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/gY0FR/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/gY0FR/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/gY0FR/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/BiIir/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/BiIir/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/BiIir/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/BiIir/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/vY9xB/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/vY9xB/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/vY9xB/trial.log (deflated 14%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/vY9xB/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/l3lCb/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/l3lCb/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/l3lCb/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/l3lCb/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Pfs7J/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Pfs7J/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Pfs7J/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Pfs7J/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/sDmeI/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/sDmeI/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/sDmeI/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/sDmeI/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/rGGSd/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/rGGSd/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/rGGSd/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/rGGSd/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/gd9sI/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/gd9sI/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/gd9sI/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/gd9sI/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/i5LSp/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/i5LSp/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/i5LSp/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/i5LSp/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Z0xIG/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Z0xIG/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Z0xIG/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Z0xIG/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/eNhHL/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/eNhHL/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/eNhHL/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/eNhHL/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/fxogA/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/fxogA/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/fxogA/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/fxogA/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/urUOE/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/urUOE/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/urUOE/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/urUOE/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/dRbTf/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/dRbTf/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/dRbTf/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/dRbTf/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/sEP3y/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/sEP3y/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/sEP3y/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/sEP3y/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/bB9p3/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/bB9p3/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/bB9p3/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/bB9p3/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/e3E8d/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/e3E8d/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/e3E8d/trial.log (deflated 17%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/e3E8d/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/lpBDX/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/lpBDX/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/lpBDX/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/lpBDX/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/bCnRs/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/bCnRs/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/bCnRs/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/bCnRs/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/d38uM/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/d38uM/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/d38uM/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/d38uM/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/fM8Mu/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/fM8Mu/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/fM8Mu/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/fM8Mu/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/dBbth/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/dBbth/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/dBbth/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/dBbth/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Fl8zR/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Fl8zR/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Fl8zR/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Fl8zR/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/vl88F/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/vl88F/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/vl88F/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/vl88F/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/oVhLT/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/oVhLT/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/oVhLT/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/oVhLT/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/VR04C/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/VR04C/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/VR04C/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/VR04C/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ddI86/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ddI86/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ddI86/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ddI86/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/iTRNH/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/iTRNH/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/iTRNH/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/iTRNH/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Lqsia/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Lqsia/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Lqsia/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/Lqsia/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/C1kYg/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/C1kYg/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/C1kYg/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/C1kYg/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/jxuqk/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/jxuqk/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/jxuqk/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/jxuqk/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/qq9Ym/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/qq9Ym/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/qq9Ym/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/qq9Ym/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/mvD4u/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/mvD4u/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/mvD4u/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/mvD4u/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/qBUqk/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/qBUqk/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/qBUqk/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/qBUqk/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/CfhLn/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/CfhLn/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/CfhLn/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/CfhLn/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/cCvF9/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/cCvF9/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/cCvF9/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/cCvF9/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/P3JSj/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/P3JSj/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/P3JSj/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/P3JSj/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/OyBhb/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/OyBhb/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/OyBhb/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/OyBhb/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ThBmC/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ThBmC/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ThBmC/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ThBmC/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/kxjxb/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/kxjxb/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/kxjxb/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/kxjxb/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/LD6he/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/LD6he/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/LD6he/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/LD6he/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/nGkpr/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/nGkpr/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/nGkpr/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/nGkpr/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/FfNYr/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/FfNYr/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/FfNYr/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/FfNYr/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/oL2he/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/oL2he/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/oL2he/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/oL2he/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/mxyDy/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/mxyDy/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/mxyDy/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/mxyDy/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/XW5BC/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/XW5BC/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/XW5BC/trial.log (deflated 14%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/XW5BC/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/M2NvH/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/M2NvH/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/M2NvH/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/M2NvH/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/C1n3o/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/C1n3o/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/C1n3o/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/C1n3o/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ZJsv7/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ZJsv7/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ZJsv7/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ZJsv7/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/IK0oP/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/IK0oP/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/IK0oP/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/IK0oP/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/uj7vF/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/uj7vF/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/uj7vF/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/uj7vF/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/tMRuC/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/tMRuC/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/tMRuC/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/tMRuC/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/TFZ7z/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/TFZ7z/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/TFZ7z/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/TFZ7z/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/JvrVA/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/JvrVA/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/JvrVA/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/JvrVA/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/bB0Cv/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/bB0Cv/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/bB0Cv/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/bB0Cv/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/JhIWO/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/JhIWO/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/JhIWO/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/JhIWO/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/a2dAh/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/a2dAh/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/a2dAh/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/a2dAh/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/YPBc6/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/YPBc6/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/YPBc6/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/YPBc6/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/SRjen/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/SRjen/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/SRjen/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/SRjen/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ASf0m/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ASf0m/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ASf0m/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/ASf0m/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/VCzg5/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/VCzg5/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/VCzg5/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/VCzg5/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/jlqdx/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/jlqdx/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/jlqdx/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/jlqdx/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/E2Dvi/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/E2Dvi/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/E2Dvi/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/E2Dvi/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/j6KYy/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/j6KYy/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/j6KYy/trial.log (deflated 14%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/j6KYy/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/uFggP/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/uFggP/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/uFggP/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/uFggP/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/HWEK7/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/HWEK7/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/HWEK7/trial.log (deflated 14%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/HWEK7/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/QOpZb/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/QOpZb/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/QOpZb/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/QOpZb/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/wGGbR/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/wGGbR/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/wGGbR/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/wGGbR/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/D8n5y/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/D8n5y/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/D8n5y/trial.log (deflated 15%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/D8n5y/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/JCYTr/ (stored 0%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/JCYTr/trial.stderr (deflated 28%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/JCYTr/trial.log (deflated 16%)
#   adding: kaggle/working/538lknex/environments/local-env/trials/JCYTr/trial.stdout (deflated 83%)
#   adding: kaggle/working/538lknex/db/ (stored 0%)
#   adding: kaggle/working/538lknex/db/nni.sqlite (deflated 95%)

# %%
# download NNI logs
from IPython.display import FileLink
FileLink(r'TPELogs.zip')
# Out:
# /kaggle/working/TPELogs.zip
