# %% [markdown]
# <a href="https://colab.research.google.com/github/antbartash/australian_rain/blob/main/MicrosoftNNI/SimulatedAnnealing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup Microsoft NNI on Google Colab / Kaggle

# %%
! pip install nni # install nni
! wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip # download ngrok and unzip it
! unzip ngrok-stable-linux-amd64.zip
# Out:
# Collecting nni
#   Obtaining dependency information for nni from https://files.pythonhosted.org/packages/0b/ed/7a061494753317e0943be1685a4690d05e2e610e5b19aa2823547b584950/nni-3.0-py3-none-manylinux1_x86_64.whl.metadata
#   Downloading nni-3.0-py3-none-manylinux1_x86_64.whl.metadata (19 kB)
# Collecting astor (from nni)
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (from nni) (2.2.1)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from nni) (0.4.6)
# Collecting filelock<3.12 (from nni)
#   Downloading filelock-3.11.0-py3-none-any.whl (10.0 kB)
# Collecting json-tricks>=3.15.5 (from nni)
#   Obtaining dependency information for json-tricks>=3.15.5 from https://files.pythonhosted.org/packages/ae/fd/e3edcf827e7f9c17c5ea1a192841dcfb1dd575a7518c25c5cadd921625b1/json_tricks-3.17.3-py2.py3-none-any.whl.metadata
#   Downloading json_tricks-3.17.3-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: nvidia-ml-py in /opt/conda/lib/python3.10/site-packages (from nni) (11.495.46)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from nni) (21.3)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from nni) (2.0.3)
# Requirement already satisfied: prettytable in /opt/conda/lib/python3.10/site-packages (from nni) (3.8.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from nni) (5.9.3)
# Collecting PythonWebHDFS (from nni)
#   Downloading PythonWebHDFS-0.2.3-py3-none-any.whl (10 kB)
# Requirement already satisfied: pyyaml>=5.4 in /opt/conda/lib/python3.10/site-packages (from nni) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from nni) (2.31.0)
# Requirement already satisfied: responses in /opt/conda/lib/python3.10/site-packages (from nni) (0.18.0)
# Collecting schema (from nni)
#   Downloading schema-0.7.5-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-learn>=0.24.1 in /opt/conda/lib/python3.10/site-packages (from nni) (1.2.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nni) (4.66.1)
# Collecting typeguard<4.1.3,>=3.0.0 (from nni)
#   Obtaining dependency information for typeguard<4.1.3,>=3.0.0 from https://files.pythonhosted.org/packages/bb/bd/dc7da80c95c920ee2b575e64901b5962ca4a1271b5f3cf6c27242aa0aafc/typeguard-4.1.2-py3-none-any.whl.metadata
#   Downloading typeguard-4.1.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting typing-extensions>=4.7.0 (from nni)
#   Obtaining dependency information for typing-extensions>=4.7.0 from https://files.pythonhosted.org/packages/b7/f4/6a90020cd2d93349b442bfcb657d0dc91eee65491600b2cb1d388bc98e6b/typing_extensions-4.9.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: websockets>=10.1 in /opt/conda/lib/python3.10/site-packages (from nni) (12.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from nni) (1.24.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from nni) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.24.1->nni) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.24.1->nni) (3.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->nni) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->nni) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->nni) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->nni) (2023.3)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prettytable->nni) (0.2.6)
# Requirement already satisfied: simplejson in /opt/conda/lib/python3.10/site-packages (from PythonWebHDFS->nni) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->nni) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->nni) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->nni) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->nni) (2023.11.17)
# Collecting contextlib2>=0.5.5 (from schema->nni)
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->nni) (1.16.0)
# Downloading nni-3.0-py3-none-manylinux1_x86_64.whl (61.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 MB 19.6 MB/s eta 0:00:00:00:0100:01
# Downloading json_tricks-3.17.3-py2.py3-none-any.whl (27 kB)
# Downloading typeguard-4.1.2-py3-none-any.whl (33 kB)
# Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Installing collected packages: json-tricks, typing-extensions, filelock, contextlib2, astor, typeguard, schema, PythonWebHDFS, nni
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.12.2
#     Uninstalling filelock-3.12.2:
#       Successfully uninstalled filelock-3.12.2
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 2.13.3
#     Uninstalling typeguard-2.13.3:
#       Successfully uninstalled typeguard-2.13.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.7 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.3 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# cuml 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# dask-cudf 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.0.3 which is incompatible.
# jupyterlab 4.0.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.1 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.1 requires jupyterlab<5.0.0a0,>=4.0.6, but you have jupyterlab 4.0.5 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.24.3 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.4 which is incompatible.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.9.0 which is incompatible.
# tensorflow-addons 0.23.0 requires typeguard<3.0.0,>=2.7, but you have typeguard 4.1.2 which is incompatible.
# tensorflow-probability 0.21.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# tensorflowjs 4.14.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.
# virtualenv 20.21.0 requires platformdirs<4,>=2.4, but you have platformdirs 4.1.0 which is incompatible.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.3 which is incompatible.
# ydata-profiling 4.5.1 requires typeguard<3,>=2.13.2, but you have typeguard 4.1.2 which is incompatible.
# Successfully installed PythonWebHDFS-0.2.3 astor-0.8.1 contextlib2-21.6.0 filelock-3.11.0 json-tricks-3.17.3 nni-3.0 schema-0.7.5 typeguard-4.1.2 typing-extensions-4.7.1
# --2023-12-24 20:30:13--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 54.161.241.46, 54.237.133.81, 18.205.222.128, ...
# Connecting to bin.equinox.io (bin.equinox.io)|54.161.241.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13921656 (13M) [application/octet-stream]
# Saving to: 'ngrok-stable-linux-amd64.zip'
#
# ngrok-stable-linux- 100%[===================>]  13.28M  36.9MB/s    in 0.4s
#
# 2023-12-24 20:30:14 (36.9 MB/s) - 'ngrok-stable-linux-amd64.zip' saved [13921656/13921656]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
! ./ngrok authtoken 2ZqSaEGuFWdJVe4YADpDuGtZ1R9_2L3tHZaAHSSavE6N96jo4 # YOUR_AUTH_TOKEN
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# clone the github repo to get the model.py file
! git clone https://github.com/antbartash/australian_rain.git
# Out:
# Cloning into 'australian_rain'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 213 (delta 64), reused 95 (delta 54), pack-reused 101
# Receiving objects: 100% (213/213), 8.24 MiB | 6.74 MiB/s, done.
# Resolving deltas: 100% (109/109), done.

# %%
from nni.experiment import Experiment
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
hyperparameter_space = {
    'n_estimators': {'_type': 'randint', '_value': [100, 2000]},
    'learning_rate': {'_type': 'loguniform', '_value': [1e-6, 0.5]},
    'depth': {'_type': 'randint', '_value': [1, 10]},
    'l2_leaf_reg': {'_type': 'uniform', '_value': [0.0, 100.0]},
    # 'random_strength': {'_type': 'uniform', '_value': [0.0, 100.0]}, # CPU only
    'bagging_temperature': {'_type': 'uniform', '_value': [0.0, 100.0]},
    'grow_policy': {'_type': 'choice', '_value': ['SymmetricTree', 'Depthwise']},
    'scale_pos_weight': {'_type': 'uniform', '_value': [1, 4]}
}

# %%
experiment = Experiment('local')
experiment.config.experiment_name = 'CatBoost_NNI_SA'
experiment.config.tuner.name = 'Anneal'
experiment.config.tuner.class_args = {
    'optimize_mode': 'maximize'
}
experiment.config.experiment_working_directory = '/kaggle/working/'
experiment.config.trial_command = 'python3 /kaggle/working/australian_rain/MicrosoftNNI/model_GPU.py'
experiment.config.trial_code_directory = '.'
experiment.config.search_space = hyperparameter_space
experiment.config.max_trial_number = 100
experiment.config.trial_concurrency = 1
experiment.config.max_experiment_duration = '1h'

# %%
get_ipython().system_raw('./ngrok http 5000 &')

# %%
! curl -s http://localhost:4040/api/tunnels # don't change the port number 4040
# Out:
# {"tunnels":[{"name":"command_line (http)","uri":"/api/tunnels/command_line%20%28http%29","public_url":"http://a7bf-34-41-105-97.ngrok-free.app","proto":"http","config":{"addr":"http://localhost:5000","inspect":true},"metrics":{"conns":{"count":0,"gauge":0,"rate1":0,"rate5":0,"rate15":0,"p50":0,"p90":0,"p95":0,"p99":0},"http":{"count":0,"rate1":0,"rate5":0,"rate15":0,"p50":0,"p90":0,"p95":0,"p99":0}}},{"name":"command_line","uri":"/api/tunnels/command_line","public_url":"https://a7bf-34-41-105-97.ngrok-free.app","proto":"https","config":{"addr":"http://localhost:5000","inspect":true},"metrics":{"conns":{"count":0,"gauge":0,"rate1":0,"rate5":0,"rate15":0,"p50":0,"p90":0,"p95":0,"p99":0},"http":{"count":0,"rate1":0,"rate5":0,"rate15":0,"p50":0,"p90":0,"p95":0,"p99":0}}}],"uri":"/api/tunnels"}

# %%
experiment.run(5000, wait_completion=True, debug=False)
# Out:
# [2023-12-24 20:30:45] Creating experiment, Experiment ID: r3jki7bm
# [2023-12-24 20:30:45] Starting web server...
# [2023-12-24 20:30:46] Setting up...
# [2023-12-24 20:30:46] Web portal URLs: http://127.0.0.1:5000 http://172.19.2.2:5000
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# True

# %%
best_trial = sorted(experiment.export_data(), key=lambda x: x.value, reverse=True)[0]
print(best_trial.parameter)
# Out:
# {'n_estimators': 1640, 'learning_rate': 0.11125449679104144, 'depth': 6, 'l2_leaf_reg': 47.249870747807364, 'bagging_temperature': 8.720267403774143, 'grow_policy': 'Depthwise', 'scale_pos_weight': 3.424001541174137}

# %%
# zip NNI logs
# !zip -r r3jki7bm.zip /kaggle/working/r3jki7bm
# Out:
#   adding: kaggle/working/r3jki7bm/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/db/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/db/nni.sqlite (deflated 95%)
#   adding: kaggle/working/r3jki7bm/checkpoint/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/log/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/log/dispatcher.log (deflated 70%)
#   adding: kaggle/working/r3jki7bm/log/nnimanager.log (deflated 90%)
#   adding: kaggle/working/r3jki7bm/log/experiment.log (deflated 50%)
#   adding: kaggle/working/r3jki7bm/environments/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/HX8WC/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/HX8WC/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/HX8WC/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/HX8WC/trial.log (deflated 15%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/gxuUU/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/gxuUU/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/gxuUU/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/gxuUU/trial.log (deflated 15%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/csR58/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/csR58/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/csR58/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/csR58/trial.log (deflated 15%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/tijmO/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/tijmO/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/tijmO/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/tijmO/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/niCI5/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/niCI5/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/niCI5/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/niCI5/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/oqewc/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/oqewc/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/oqewc/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/oqewc/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/ls7D8/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/ls7D8/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/ls7D8/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/ls7D8/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/m3g3f/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/m3g3f/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/m3g3f/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/m3g3f/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/w28WG/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/w28WG/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/w28WG/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/w28WG/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/MCYFB/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/MCYFB/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/MCYFB/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/MCYFB/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/zrGvy/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/zrGvy/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/zrGvy/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/zrGvy/trial.log (deflated 15%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/fOmPB/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/fOmPB/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/fOmPB/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/fOmPB/trial.log (deflated 15%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/AmYpO/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/AmYpO/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/AmYpO/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/AmYpO/trial.log (deflated 15%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/QSrdJ/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/QSrdJ/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/QSrdJ/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/QSrdJ/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/pSsYl/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/pSsYl/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/pSsYl/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/pSsYl/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/NX0HW/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/NX0HW/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/NX0HW/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/NX0HW/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/UdCMu/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/UdCMu/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/UdCMu/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/UdCMu/trial.log (deflated 15%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/Va3HW/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/Va3HW/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/Va3HW/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/Va3HW/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/f6Cv9/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/f6Cv9/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/f6Cv9/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/f6Cv9/trial.log (deflated 15%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/sxr7k/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/sxr7k/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/sxr7k/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/sxr7k/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/iyH4J/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/iyH4J/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/iyH4J/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/iyH4J/trial.log (deflated 15%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/kSY4f/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/kSY4f/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/kSY4f/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/kSY4f/trial.log (deflated 15%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/ZRHhl/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/ZRHhl/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/ZRHhl/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/ZRHhl/trial.log (deflated 15%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/WrUFX/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/WrUFX/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/WrUFX/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/WrUFX/trial.log (deflated 15%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/BY9ra/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/BY9ra/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/BY9ra/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/BY9ra/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/hFXSe/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/hFXSe/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/hFXSe/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/hFXSe/trial.log (deflated 15%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/Ehfyb/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/Ehfyb/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/Ehfyb/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/Ehfyb/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/kqWAx/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/kqWAx/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/kqWAx/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/kqWAx/trial.log (deflated 14%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/rim7e/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/rim7e/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/rim7e/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/rim7e/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/DOXIg/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/DOXIg/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/DOXIg/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/DOXIg/trial.log (deflated 15%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/D2r5y/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/D2r5y/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/D2r5y/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/D2r5y/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/VPpAj/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/VPpAj/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/VPpAj/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/VPpAj/trial.log (deflated 14%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/Hk2yv/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/Hk2yv/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/Hk2yv/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/Hk2yv/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/FBZKi/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/FBZKi/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/FBZKi/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/FBZKi/trial.log (deflated 16%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/LIQvB/ (stored 0%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/LIQvB/trial.stdout (deflated 83%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/LIQvB/trial.stderr (deflated 28%)
#   adding: kaggle/working/r3jki7bm/environments/local-env/trials/LIQvB/trial.log (deflated 16%)

# %%
# download NNI logs
from IPython.display import FileLink
FileLink(r'r3jki7bm.zip')
# Out:
# /kaggle/working/r3jki7bm.zip
